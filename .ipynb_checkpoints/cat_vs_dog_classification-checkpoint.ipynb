# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, BatchNormalization, Flatten, Dropout
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
                rescale=1./255,
                shear_range=0.2,
                zoom_range=0.2,
                horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
batch_size = 20

train_generator = train_datagen.flow_from_directory(
        'train',
        target_size=(256,256),
        batch_size=batch_size,
        class_mode='binary')

test_generator = test_datagen.flow_from_directory(
        'test',
        target_size=(256,256),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# Found 20000 images belonging to 2 classes.
# Found 4999 images belonging to 2 classes.

# %%
import tensorflow as tf

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(256,256,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 254, 254, 32)      896
#
#  batch_normalization_8 (Batc  (None, 254, 254, 32)     128
#  hNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 127, 127, 32)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 125, 125, 64)      18496
#
#  batch_normalization_9 (Batc  (None, 125, 125, 64)     256
#  hNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 60, 60, 128)       73856
#
#  batch_normalization_10 (Bat  (None, 60, 60, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 30, 30, 128)      0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 115200)            0
#
#  dense_6 (Dense)             (None, 64)                7372864
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 7,467,073
# Trainable params: 7,466,625
# Non-trainable params: 448
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_generator, steps_per_epoch=20000//batch_size, epochs=20, validation_data=test_generator, validation_steps= 5000 // batch_size)
# Out:
# Epoch 1/20
# 1000/1000 [==============================] - 649s 647ms/step - loss: 1.5919 - accuracy: 0.5753 - val_loss: 0.6041 - val_accuracy: 0.6865
# Epoch 2/20
# 1000/1000 [==============================] - 495s 495ms/step - loss: 0.6708 - accuracy: 0.6600 - val_loss: 0.6223 - val_accuracy: 0.7558
# Epoch 3/20
# 1000/1000 [==============================] - 538s 538ms/step - loss: 0.6080 - accuracy: 0.7097 - val_loss: 0.6136 - val_accuracy: 0.6509
# Epoch 4/20
# 1000/1000 [==============================] - 799s 800ms/step - loss: 0.5866 - accuracy: 0.7213 - val_loss: 0.9531 - val_accuracy: 0.7447
# Epoch 5/20
# 1000/1000 [==============================] - 644s 643ms/step - loss: 0.5714 - accuracy: 0.7312 - val_loss: 1.1509 - val_accuracy: 0.6557
# Epoch 6/20
# 1000/1000 [==============================] - 552s 552ms/step - loss: 0.5754 - accuracy: 0.7340 - val_loss: 0.9077 - val_accuracy: 0.7974
# Epoch 7/20
# 1000/1000 [==============================] - 437s 437ms/step - loss: 0.5745 - accuracy: 0.7326 - val_loss: 1.1939 - val_accuracy: 0.7786
# Epoch 8/20
# 1000/1000 [==============================] - 531s 531ms/step - loss: 0.5727 - accuracy: 0.7399 - val_loss: 0.6543 - val_accuracy: 0.7726
# Epoch 9/20
# 1000/1000 [==============================] - 502s 502ms/step - loss: 0.5543 - accuracy: 0.7515 - val_loss: 1.3841 - val_accuracy: 0.7684
# Epoch 10/20
# 1000/1000 [==============================] - 512s 512ms/step - loss: 0.5312 - accuracy: 0.7645 - val_loss: 0.5387 - val_accuracy: 0.8124
# Epoch 11/20
# 1000/1000 [==============================] - 506s 506ms/step - loss: 0.5197 - accuracy: 0.7713 - val_loss: 0.4654 - val_accuracy: 0.7844
# Epoch 12/20
# 1000/1000 [==============================] - 352s 352ms/step - loss: 0.5203 - accuracy: 0.7753 - val_loss: 1.1293 - val_accuracy: 0.7061
# Epoch 13/20
# 1000/1000 [==============================] - 410s 410ms/step - loss: 0.4876 - accuracy: 0.7926 - val_loss: 0.3925 - val_accuracy: 0.8274
# Epoch 14/20
# 1000/1000 [==============================] - 318s 318ms/step - loss: 0.4830 - accuracy: 0.7977 - val_loss: 0.4333 - val_accuracy: 0.7940
# Epoch 15/20
# 1000/1000 [==============================] - 588s 588ms/step - loss: 0.4575 - accuracy: 0.8055 - val_loss: 0.4634 - val_accuracy: 0.8392
# Epoch 16/20
# 1000/1000 [==============================] - 443s 443ms/step - loss: 0.4310 - accuracy: 0.8187 - val_loss: 0.4534 - val_accuracy: 0.8020
# Epoch 17/20
# 1000/1000 [==============================] - 408s 408ms/step - loss: 0.4380 - accuracy: 0.8219 - val_loss: 1.5544 - val_accuracy: 0.7932
# Epoch 18/20
# 1000/1000 [==============================] - 410s 410ms/step - loss: 0.4234 - accuracy: 0.8277 - val_loss: 3.4499 - val_accuracy: 0.6641
# Epoch 19/20
# 1000/1000 [==============================] - 460s 460ms/step - loss: 0.4107 - accuracy: 0.8390 - val_loss: 0.5534 - val_accuracy: 0.8426
# Epoch 20/20
# 1000/1000 [==============================] - 489s 488ms/step - loss: 0.4119 - accuracy: 0.8358 - val_loss: 0.4892 - val_accuracy: 0.8560

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], color='red', label='Train')
plt.plot(history.history['val_accuracy'], color='blue', label='Test')
plt.title("Accuracy vs Validation Accuracy")
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], color='red', label='Train')
plt.plot(history.history['val_loss'], color='blue', label='Test')
plt.title("Loss vs Validation Loss")
plt.legend()
plt.show()

# %%
model.save('model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model\assets
# INFO:tensorflow:Assets written to: model\assets
